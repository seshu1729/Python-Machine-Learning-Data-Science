# %%
name = "Seshu"
age = 25

print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(name.upper())
# Out:
# SESHU

# %%
print(age.is_integer())
# Out:
# True

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

    def bark(self):
        print("Whoof Whoof")

dog1 = Dog("Bruce", "Terrier")
dog1.bark()
print(dog1.name)
print(dog1.breed)

print("------------------")
dog2 = Dog("Freya", "Greyhound")
dog2.bark()
print(dog2.name)
print(dog2.breed)
# Out:
# Whoof Whoof
# Bruce
# Terrier
# ------------------
# Whoof Whoof
# Freya
# Greyhound

# %%
class Dog:
    def __init__(self, name, breed, owner):
        self.name = name
        self.breed = breed
        self.owner = owner

    def bark(self):
        print("Whoof Whoof")

class Owner:
    def __init__(self, name, address, contact_number):
        self.name = name
        self.address = address
        self.phone_number = contact_number

owner1 = Owner("Sally", "412 Springfield", "888-999")
dog1 = Dog("Bruce", "Terrier", owner1)
print(dog1.owner.name)

print("------------------")
owner2 = Owner("Danny", "123 Springfield", "444-888-999")
dog2 = Dog("Freya", "Greyhound", owner2)
print(dog2.owner.name)
# Out:
# Sally
# ------------------
# Danny

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old")

person1 = Person("Alice", 30)
person1.greet()

person2 = Person("Bob", 42)
person2.greet()
# Out:
# Hello, my name is Alice and I am 30 years old
# Hello, my name is Bob and I am 42 years old

# %%
class User:
    def __init__(self, username, email, password):
        self.username = username
        self.email = email
        self.password = password

    def say_hi_to_user(self, user):
        print(f"Sending meesage to {user.username}: Hi {user.username}, it's {self.username}")        

user1 = User("dantheman", "dan@gmail.com", "123")
user2 = User("batman", "bat@outlook.com", "abc")

print("===========")
print(user1.email)
user1.email = "dan2@gmai;.com"
print(user1.email)
print("===========")
user1.say_hi_to_user(user2)
# Out:
# ...
# dan@gmail.com
# dan2@gmai;.com
# ...
# Sending meesage to batman: Hi batman, it's dantheman

# %%
# accessing and Modifying data:
# 1. The traditional way: make the data private and use getters and setters:

class User:
    def __init__(self, username, email, password):
        self.username = username
        self._email = email # Protected
        self.password = password

    def clean_email(self):
        return self._email.lower().strip()

user1 = User("dantheman", "Dan@gmail.com ", "123")

print(user1._email)
user1._email = "         Adsadsadad@g mail.com   "
print(user1.clean_email())
# Out:
# Dan@gmail.com
# adsadsadad@g mail.com

# %%
# accessing and Modifying data:
# 1. The traditional way: make the data private and use getters and setters:

class User:
    def __init__(self, username, email, password):
        self.username = username
        self.__email = email # Private
        self.password = password

    def clean_email(self):
        return self.__email.lower().strip()

user1 = User("dantheman", "Dan@gmail.com ", "123")

print(user1.__email)
user1.__email = "         Adsadsadad@g mail.com   "
print(user1.clean_email())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 15
#      11         return self.__email.lower().strip()
#      13 user1 = User("dantheman", "Dan@gmail.com ", "123")
# ---> 15 print(user1.__email)
#      16 user1.__email = "         Adsadsadad@g mail.com   "
#      17 print(user1.clean_email())
#
# AttributeError: 'User' object has no attribute '__email'

# %%
# We'll get error because we are accessing the email attribute outside of the class.. 3 small examples included

# %%
# Some examples of public, private and protected

class Person:
    def __init__(self, name):
        self.name = name  # public

p = Person("Alice")
print(p.name)  # Allowed
# Out:
# Alice

# %%
class Car:
    def __init__(self):
        self._speed = 50  # protected

my_car = Car()
print(my_car._speed)  # Allowed but discouraged (convention only)
# Out:
# 50

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # private

account = BankAccount(1000)
print(account.__balance)  # ❌ AttributeError

# But you *can* still access it like this:
# print(account._BankAccount__balance)  # Not recommended
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 6
#       3         self.__balance = balance  # private
#       5 account = BankAccount(1000)
# ----> 6 print(account.__balance)  # ❌ AttributeError
#       8 # But you *can* still access it like this:
#       9 # print(account._BankAccount__balance)  # Not recommended
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %%
# 1 example, which consists of all the variables

class Device:
    def __init__(self, name):
        self.name = name              # public: safe for external use
        self._status = "off"          # protected: internal state
        self.__secret_key = "XYZ123"  # private: must be hidden

    def turn_on(self):
        """Public method others can call."""
        self._status = "on"           # using protected attribute internally

    def get_status(self):
        """Public friendly access."""
        return self._status

    def __authenticate(self):         # private method
        return f"Auth with {self.__secret_key}"

d = Device("Camera")

# Public access → OK
print(d.name)
print(d.get_status())

# Protected access → allowed, but discouraged (internal detail)
print(d._status)

# Private access → not allowed directly
# print(d.__secret_key)   # ❌ AttributeError

# Name-mangled private access (possible but NOT recommended)
print(d._Device__secret_key)
# Out:
# Camera
# off
# off
# XYZ123

# %%
# accessing and Modifying data:
# 1. The traditional way: make the data private and use getters and setters:

class User:
    def __init__(self, username, email, password):
        self.username = username
        self._email = email # Protected
        self.password = password

    def get_email(self):
        return self._email

    def set_email(self, new_email):
        self._email = new_email

user1 = User("dantheman", "Dan@gmail.com ", "123")
print(user1.get_email())

user1.set_email("danny@outlook.com")
print(user1.get_email())
# Out:
# Dan@gmail.com
# danny@outlook.com

# %%
# Just added datetime
from datetime import datetime
class User:
    def __init__(self, username, email, password):
        self.username = username
        self._email = email # Protected
        self.password = password

    def get_email(self):
        print(f"Email accessed at {datetime.now()}")
        return self._email

    def set_email(self, new_email):
        self._email = new_email

user1 = User("dantheman", "Dan@gmail.com ", "123")
print(user1.get_email())

user1.set_email("danny@outlook.com")
print(user1.get_email())
# Out:
# Email accessed at 2025-12-04 12:32:58.641517
# Dan@gmail.com
# Email accessed at 2025-12-04 12:32:58.653862
# danny@outlook.com

# %%
# Optional: Just an example to understand more about @property

class User:
    def __init__(self, balance):
        self._balance = balance

    @property
    def balance(self):
        print("Getter called")
        return self._balance

    @balance.setter
    def balance(self, value):
        print("Setter called")
        self._balance = value


user1 = User(100)

print(user1.balance)    # calling getter
user1.balance = 400     # calling setter
# Out:
# Getter called
# 100
# Setter called

# %%
from datetime import datetime
class User:
    def __init__(self, username, email, password):
        self.username = username
        self._email = email # Protected
        self.password = password

    @property
    def email(self):
        print("Email accessed")
        return self._email

    @email.setter
    def email(self, new_email):
        if "@" in new_email:
            self._email = newEmail

user1 = User("dantheman", "dan@gmail.com ", "123")
user1.email = "this is not an email"
print(user1.email)
# Out:
# Email accessed
# dan@gmail.com

# %%
class User:
    # Static attribute to count all users
    user_count = 0

    def __init__(self, username, email):
        self.username = username  # Instance attribute
        self.email = email  # Instance attribute
        User.user_count += 1  # Increment the static attribute

    def display_user(self):
        print(f"Username: {self.username}, Email: {self.email}")


# Accessing static attribute
print(User.user_count)
print("-------------------")
# Creating user instances
user1 = User("dantheman", "dan@gmail.com")
user2 = User("sally123", "sally@gmail.com")

# Accessing instance attributes
print(user1.username)  # Output: dantheman
print(user2.username)  # Output: sally123

# Accessing static attribute
print(User.user_count)  # Output: 2
print(
    user1.user_count
)  # Output: 2 (but it's still shared, as this accesses User.user_count)
print(
    user2.user_count
)  # Output: 2 (but it's still shared, as this accesses User.user_count)
# Out:
# 0
# -------------------
# dantheman
# sally123
# 2
# 2
# 2

# %%
# Static vs. Instance Method example

class BankAccount:
    MIN_BALANCE = 100  # Class/static attribute, minimum balance requirement

    def __init__(self, owner, balance=0):
        self.owner = owner  # Instance attribute
        self._balance = balance  # Instance attribute

    # Instance method
    def deposit(self, amount):
        """Add amount to the account balance."""
        if amount > 0:
            self._balance += amount
            print(f"{self.owner}'s new balance: ${self._balance}")
        else:
            print("Deposit amount must be positive.")

    # Static method
    @staticmethod
    def is_valid_interest_rate(rate):
        """Check if the interest rate is within a valid range (0 to 5%)."""
        return 0 <= rate <= 5


# Example usage
account = BankAccount("Alice", 500)

# Using instance method
account.deposit(200)  # Output: Alice's new balance: $700

# Using static method
print(BankAccount.is_valid_interest_rate(3))  # Output: True
print(BankAccount.is_valid_interest_rate(10))  # Output: False

# Example:
class Person:
    def __init__(self, name, email, address) -> None:
        self.name = name  # public attribute
        self._email = email  # protected attribute
        self.__home_address = address  # private attribute

    def print_details(self):
        print(
            f"Name: {self.name}; Email: {self._email}; Address: {self.__home_address}"
        )


person = Person("danny", "danny@gmail.com", "200 Springfield way, UK")
person.print_details()  # Name: danny; Email: danny@gmail.com; Address: 200 Springfield way, UK

print(person.name)  # danny
print(person._email)  # danny@gmail.com (but we are not supposed to do this!)
print(
    person.__home_address
)  # AttributeError: 'Person' object has no attribute '__home_address'
# Out:
# Alice's new balance: $700
# True
# False
# Name: danny; Email: danny@gmail.com; Address: 200 Springfield way, UK
# danny
# danny@gmail.com
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 55
#      52 print(person.name)  # danny
#      53 print(person._email)  # danny@gmail.com (but we are not supposed to do this!)
#      54 print(
# ---> 55     person.__home_address
#      56 )  # AttributeError: 'Person' object has no attribute '__home_address'
#
# AttributeError: 'Person' object has no attribute '__home_address'
